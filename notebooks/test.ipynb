# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
response=llm.invoke("who's the pm of india")

# %%
print(response.content)
# Out:
# The Prime Minister of India is **Narendra Modi**.

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper

# %%
search = GoogleSerperAPIWrapper()
tool=[search.run]

# %%
from langchain.agents import create_agent

# %%
from langgraph.checkpoint.memory import MemorySaver

# %%
agent = create_agent(
    model = llm ,
    tools=tool,
    system_prompt="you are an amazing agent you can search on google"
)

# %%
question = "what is current temperature in mohali"

# %%
response= agent.invoke({"messages":[{"role":"user","content":question}]})

# %%
print(response["messages"][-1].content)
# Out:
# The current temperature in Mohali (Punjab, India) is **about 64 °F (≈ 18 °C)**, with a mostly cloudy sky.
